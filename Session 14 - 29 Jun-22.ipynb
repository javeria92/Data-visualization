# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Principle of proximity

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
#
# ![img](https://s3.amazonaws.com/dq-content/527/2.2-m527.gif)
#
#
#
# ![img](https://s3.amazonaws.com/dq-content/527/2.3-m527.gif)
#
#
#
# ![image-3.png](attachment:image-3.png)
#
#
#
#
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # Priniciple of Similarity

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
#
# ![image-2.png](attachment:image-2.png)
#
#
#
# ![image-3.png](attachment:image-3.png)
#
#
#
# ![image-4.png](attachment:image-4.png)
#
#
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# # Principle of Enclosure

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
#
#
# ![image-2.png](attachment:image-2.png)
#
#
#
#
# ![image-3.png](attachment:image-3.png)
#
#
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # Principle of Cinnection

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)
#
#
# ![image-3.png](attachment:image-3.png)
#
#
# ![image-4.png](attachment:image-4.png)
#
#
# ![image-5.png](attachment:image-5.png)
