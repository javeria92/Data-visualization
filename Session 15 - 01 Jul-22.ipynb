# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
w_wine = pd.read_csv("w.csv",sep = ";")
r_wine = pd.read_csv("r.csv", delimiter = ";")

# %%
w_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
r_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
# plt.style.use('ggplot')

# plt.style.use("default")

# plt.style.use('seaborn-ticks')

# %%
w_wine.corr()["quality"][:-1].abs().sort_values(ascending = False)
# Out:
# alcohol                 0.435575
# density                 0.307123
# chlorides               0.209934
# volatile acidity        0.194723
# total sulfur dioxide    0.174737
# fixed acidity           0.113663
# pH                      0.099427
# residual sugar          0.097577
# sulphates               0.053678
# citric acid             0.009209
# free sulfur dioxide     0.008158
# Name: quality, dtype: float64

# %%
w_corr = w_wine.corr()["quality"][:-1]
r_corr = r_wine.corr()["quality"][:-1]

# %%
r_corr
# Out:
# fixed acidity           0.124052
# volatile acidity       -0.390558
# citric acid             0.226373
# residual sugar          0.013732
# chlorides              -0.128907
# free sulfur dioxide    -0.050656
# total sulfur dioxide   -0.185100
# density                -0.174919
# pH                     -0.057731
# sulphates               0.251397
# alcohol                 0.476166
# Name: quality, dtype: float64

# %%
plt.style.use("fivethirtyeight")

fig, ax = plt.subplots(figsize = (9,5))


ax.barh(w_corr.index, w_corr.values)
ax.barh(r_corr.index, r_corr)


plt.show()

# %%
fig, ax = plt.subplots(figsize = (9,5))


ax.barh(w_corr.index, w_corr.values, left = 2)
ax.barh(r_corr.index, r_corr, left = -0.1)


plt.show()

# %%
fig, ax = plt.subplots(figsize = (9,5))


ax.barh(w_corr.index, w_corr.values, left = 2)
ax.barh(r_corr.index, r_corr, left = -0.1)
ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])


plt.show()

# %%
l = w_corr.index
l1 = [s.title() for s in w_corr.index]


coord = [0.71,0.67,0.76, 0.67, 0.77, 0.6,0.59,0.8, 0.91, 0.77,0.82]

# %%
# 'fixed acidity'.title()

# %%
fig, ax = plt.subplots(figsize = (9,5))


ax.barh(w_corr.index, w_corr.values, left = 2)
ax.barh(r_corr.index, r_corr, left = -0.1)
ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])

x_coord = dict(zip(l1,coord))
y_coord = -0.2

for label, x in x_coord.items():
    ax.text(x,y_coord,label)
    y_coord += 1


plt.show()

# %%
x,y_coord, label
# Out:
# (0.82, 10.8, 'Alcohol')

# %%
fig, ax = plt.subplots(figsize = (9,5))


ax.barh(w_corr.index, w_corr.values, left = 2)
ax.barh(r_corr.index, r_corr, left = -0.1)
ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])

x_coord = dict(zip(l1,coord))
y_coord = -0.2

for label, x in x_coord.items():
    ax.text(x,y_coord,label)
    y_coord += 1

ax.axvline(0.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )
ax.axvline(1.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )
plt.show()

# %%
fig, ax = plt.subplots(figsize = (9,5))

ax.barh(w_corr.index, w_corr.values, left = 2)
ax.barh(r_corr.index, r_corr, left = -0.1)
ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])

x_coord = dict(zip(l1,coord))
y_coord = -0.2

for label, x in x_coord.items():
    ax.text(x,y_coord,label)
    y_coord += 1

ax.axvline(0.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )
ax.axvline(1.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )

ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.68, xmax = 0.98  )

plt.show()

# %%
fig, ax = plt.subplots(figsize = (9,5))

ax.barh(w_corr.index, w_corr.values, left = 2)
ax.barh(r_corr.index, r_corr, left = -0.1)
ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])

x_coord = dict(zip(l1,coord))
y_coord = -0.2

for label, x in x_coord.items():
    ax.text(x,y_coord,label)
    y_coord += 1

ax.axvline(0.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )
ax.axvline(1.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )

ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98  )

ax.text(-0.7,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)
ax.text(1.43,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)

plt.show()

# %%
fig, ax = plt.subplots(figsize = (9,5))

ax.barh(w_corr.index, w_corr.values, left = 2)
ax.barh(r_corr.index, r_corr, left = -0.1)
ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])

x_coord = dict(zip(l1,coord))
y_coord = -0.2

for label, x in x_coord.items():
    ax.text(x,y_coord,label)
    y_coord += 1

ax.axvline(0.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )
ax.axvline(1.42, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )

ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98  )

ax.text(-0.7,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)
ax.text(1.43,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)

ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98  )

plt.show()

# %%
fig, ax = plt.subplots(figsize = (9,5))

ax.barh(w_corr.index, w_corr.values, left = 2)
ax.barh(r_corr.index, r_corr, left = -0.1)
ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])

x_coord = dict(zip(l1,coord))
y_coord = -0.2

for label, x in x_coord.items():
    ax.text(x,y_coord,label)
    y_coord += 1

ax.axvline(0.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )
ax.axvline(1.42, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )

ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98  )

ax.text(-0.7,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)
ax.text(1.43,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)

ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98  )

ax.text(-0.3,11.3, "RED WINE",weight = "bold" )
ax.text(1.75,11.3, "WHITE WINE", weight = "bold" )


plt.show()

# %%
fig, ax = plt.subplots(figsize = (9,5))

ax.barh(w_corr.index, w_corr.values, left = 2, height = 0.45)
ax.barh(r_corr.index, r_corr, left = -0.1, height = 0.45)
ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])

x_coord = dict(zip(l1,coord))
y_coord = -0.2

for label, x in x_coord.items():
    ax.text(x,y_coord,label)
    y_coord += 1

ax.axvline(0.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )
ax.axvline(1.42, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )

ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98  )

ax.text(-0.7,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)
ax.text(1.43,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)

ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98  )

ax.text(-0.3,11.3, "RED WINE",weight = "bold" )
ax.text(1.75,11.3, "WHITE WINE", weight = "bold" )

ax.text(-0.7, -2.9,"@NED" + " "*53+ "Source: DATA SCIENCE",
        color = "white", backgroundcolor = "#4d4d4d", weight = "bold", size = 18)


plt.show()

# %%
fig, ax = plt.subplots(figsize = (9,5))

ax.barh(w_corr.index, w_corr.values, left = 2, height = 0.45)
ax.barh(r_corr.index, r_corr, left = -0.1, height = 0.45)
ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])

x_coord = dict(zip(l1,coord))
y_coord = -0.2

for label, x in x_coord.items():
    ax.text(x,y_coord,label)
    y_coord += 1

ax.axvline(0.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )
ax.axvline(1.42, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )

ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98  )

ax.text(-0.7,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)
ax.text(1.43,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)

ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98  )

ax.text(-0.3,11.3, "RED WINE",weight = "bold" )
ax.text(1.75,11.3, "WHITE WINE", weight = "bold" )

ax.text(-0.7, -2.9,"@NED" + " "*53+ "Source: DATA SCIENCE",
        color = "white", backgroundcolor = "#4d4d4d", weight = "bold", size = 18)


ax.text(-0.7,13.5, "Wine Quality Most Strongly Correlated With Alchol Level", size = 17, weight = "bold")
ax.text(-0.7,12.7, "Correltaion values between wine quality and wine properties (Honey)")

plt.show()

# %%
white_corr = w_corr>=0

red_corr = r_corr>=0

# %%
d = {True:"#33a1c9", False: "#ffae42"}

w_map = white_corr.replace(d)
r_map = red_corr.map(d)

# %%
fig, ax = plt.subplots(figsize = (9,5))

ax.barh(w_corr.index, w_corr.values, left = 2, height = 0.45, color =w_map )
ax.barh(r_corr.index, r_corr, left = -0.1, height = 0.45, color =r_map )

ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])

x_coord = dict(zip(l1,coord))
y_coord = -0.2

for label, x in x_coord.items():
    ax.text(x,y_coord,label)
    y_coord += 1

ax.axvline(0.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )
ax.axvline(1.42, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )

ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32)
ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98)

ax.text(-0.7,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)
ax.text(1.43,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)

ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32)
ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98)

ax.text(-0.3,11.3, "RED WINE",weight = "bold" )
ax.text(1.75,11.3, "WHITE WINE", weight = "bold")

ax.text(-0.7, -2.9,"@NED" + " "*53+ "Source: DATA SCIENCE",
        color = "white", backgroundcolor = "#4d4d4d", weight = "bold", size = 18)


ax.text(-0.7,13.5, "Wine Quality Most Strongly Correlated With Alchol Level", size = 17, weight = "bold")
ax.text(-0.7,12.7, "Correltaion values between wine quality and wine properties (Honey)")

plt.show()
