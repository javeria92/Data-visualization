# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
deaths = pd.read_csv("avg_deaths.csv")

deaths.head()
# Out:
#    Month  New_deaths
# 0      1           0
# 1      2           0
# 2      3          77
# 3      4        1844
# 4      5        1448

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize = (6,8))

ax1.plot(deaths["Month"],deaths["New_deaths"])
ax2.plot(deaths["Month"],deaths["New_deaths"])
ax3.plot(deaths["Month"],deaths["New_deaths"])
ax4.plot(deaths["Month"],deaths["New_deaths"])

plt.show()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize = (6,8))


axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(deaths["Month"],deaths["New_deaths"])

plt.show()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize = (6,8))


axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(deaths["Month"],deaths["New_deaths"])
    ax.set_yticklabels([])
    ax.set_xticklabels([])

plt.show()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize = (6,8))


axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(deaths["Month"],deaths["New_deaths"])
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    

plt.show()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize = (6,8))


axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(deaths["Month"],deaths["New_deaths"])
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = False)
    for spine in ax.spines.values():
        spine.set_visible(0)
    

plt.show()

# %%
deaths
# Out:
#     Month  New_deaths
# 0       1           0
# 1       2           0
# 2       3          77
# 3       4        1844
# 4       5        1448
# 5       6         785
# 6       7         769
# 7       8        1020
# 8       9         739
# 9      10         751
# 10     11        1225
# 11     12        2247

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize = (6,8))


axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(deaths["Month"],deaths["New_deaths"], color = "#af0b1e", alpha = 0.1)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = False)
    for spine in ax.spines.values():
        spine.set_visible(0)

ax1.plot(deaths["Month"][:3], deaths["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(deaths.loc[2:5,"Month"], deaths.loc[2:5,"New_deaths"], color = "#af0b1e", linewidth = 2.5)
ax3.plot(deaths["Month"][5:10], deaths["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(deaths["Month"][9:12], deaths["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)

plt.show()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize = (6,8))


axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(deaths["Month"],deaths["New_deaths"], color = "#af0b1e", alpha = 0.1)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = False)
    for spine in ax.spines.values():
        spine.set_visible(0)

ax1.plot(deaths["Month"][:3], deaths["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(deaths.loc[2:5,"Month"], deaths.loc[2:5,"New_deaths"], color = "#af0b1e", linewidth = 2.5)
ax3.plot(deaths["Month"][5:10], deaths["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(deaths["Month"][9:12], deaths["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)

ax1.text(0.5, -80, "0", alpha = 0.5)
ax1.text(3.5, 2000, "1844", alpha = 0.5)
ax1.text(11.5, 2400, "2247", alpha = 0.5)

plt.show()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize = (6,8))


axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(deaths["Month"],deaths["New_deaths"], color = "#af0b1e", alpha = 0.1)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = False)
    for spine in ax.spines.values():
        spine.set_visible(0)

ax1.plot(deaths["Month"][:3], deaths["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(deaths.loc[2:5,"Month"], deaths.loc[2:5,"New_deaths"], color = "#af0b1e", linewidth = 2.5)
ax3.plot(deaths["Month"][5:10], deaths["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(deaths["Month"][9:12], deaths["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)

ax1.text(0.5, -80, "0", alpha = 0.5)
ax1.text(3.5, 2000, "1844", alpha = 0.5)
ax1.text(11.5, 2400, "2247", alpha = 0.5)

ax1.text(1.1, -300, "Jan - Mar", color = "#af0b1e", rotation = 2.5, weight = "bold")
ax2.text(3.6, 800, "Mar - Jun", color = "#af0b1e", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#af0b1e", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#af0b1e", weight = "bold", rotation = 45)

plt.show()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize = (6,8))


axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(deaths["Month"],deaths["New_deaths"], color = "#af0b1e", alpha = 0.1)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = False)
    for spine in ax.spines.values():
        spine.set_visible(0)

ax1.plot(deaths["Month"][:3], deaths["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(deaths.loc[2:5,"Month"], deaths.loc[2:5,"New_deaths"], color = "#af0b1e", linewidth = 2.5)
ax3.plot(deaths["Month"][5:10], deaths["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(deaths["Month"][9:12], deaths["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)

ax1.text(0.5, -80, "0", alpha = 0.5)
ax1.text(3.5, 2000, "1844", alpha = 0.5)
ax1.text(11.5, 2400, "2247", alpha = 0.5)

ax1.text(1.1, -300, "Jan - Mar", color = "#af0b1e", rotation = 2.5, weight = "bold")
ax2.text(3.6, 800, "Mar - Jun", color = "#af0b1e", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#af0b1e", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#af0b1e", weight = "bold", rotation = 45)

ax1.text(0.5, 3500, "Stroytelling of Covid 19 in USA", weight = "bold", size = 15)
ax1.text(0.5, 3100, "Monthly Average Covid's Death", size = 12)

for ax in axes:
    ax.axhline(1600, xmin = 0.5, xmax = 0.8, color = "#af0b1e", linewidth = 6, alpha = 0.1)


plt.show()

# %%
deaths["days"] = [31,28,31,30,31,30,31,31,30,31,30,31]

# %%
deaths.rename({"days":"Days"}, axis = 1, inplace = True)

# %%
deaths["Month_Death"] = deaths["New_deaths"] * deaths["Days"]

# %%
deaths["Cummulative_death"] = deaths["Month_Death"].cumsum()

# %%
deaths
# Out:
#     Month  New_deaths  Days  Month_Death  Cummulative_death
# 0       1           0    31            0                  0
# 1       2           0    28            0                  0
# 2       3          77    31         2387               2387
# 3       4        1844    30        55320              57707
# 4       5        1448    31        44888             102595
# 5       6         785    30        23550             126145
# 6       7         769    31        23839             149984
# 7       8        1020    31        31620             181604
# 8       9         739    30        22170             203774
# 9      10         751    31        23281             227055
# 10     11        1225    30        36750             263805
# 11     12        2247    31        69657             333462

# %%
d = [2387,126145, 227055, 295406]

prop = []

for i in d:
    prop.append(round(i/d[-1], 2))
# Out:
# 0.008080404595708957
# 0.42702247076904326
# 0.7686201363547118
# 1.0

# %%
prop
# Out:
# [0.01, 0.43, 0.77, 1.0]

# %%
xmin = 0.5

xmax = []

for i in prop:
    v = 0.5 + i*0.3
    xmax.append(v)

# %%
xmax
# Out:
# [0.503, 0.629, 0.731, 0.8]

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize = (6,8))


axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(deaths["Month"],deaths["New_deaths"], color = "#af0b1e", alpha = 0.1)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = False)
    for spine in ax.spines.values():
        spine.set_visible(0)

ax1.plot(deaths["Month"][:3], deaths["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(deaths.loc[2:5,"Month"], deaths.loc[2:5,"New_deaths"], color = "#af0b1e", linewidth = 2.5)
ax3.plot(deaths["Month"][5:10], deaths["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(deaths["Month"][9:12], deaths["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)

ax1.text(0.5, -80, "0", alpha = 0.5)
ax1.text(3.5, 2000, "1844", alpha = 0.5)
ax1.text(11.5, 2400, "2247", alpha = 0.5)

ax1.text(1.1, -300, "Jan - Mar", color = "#af0b1e", rotation = 2.5, weight = "bold")
ax2.text(3.6, 800, "Mar - Jun", color = "#af0b1e", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#af0b1e", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#af0b1e", weight = "bold", rotation = 45)

ax1.text(0.5, 3500, "Stroytelling of Covid 19 in USA", weight = "bold", size = 15)
ax1.text(0.5, 3100, "Monthly Average Covid's Death", size = 12)

for ax,xm in zip(axes, xmax):
    ax.axhline(1600, xmin = 0.5, xmax = 0.8, color = "#af0b1e", linewidth = 6, alpha = 0.1)
    ax.axhline(1600, xmin = 0.5, xmax = xm, color = "#af0b1e", linewidth = 6, )



plt.show()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize = (6,8))


axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(deaths["Month"],deaths["New_deaths"], color = "#af0b1e", alpha = 0.1)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = False)
    for spine in ax.spines.values():
        spine.set_visible(0)

ax1.plot(deaths["Month"][:3], deaths["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(deaths.loc[2:5,"Month"], deaths.loc[2:5,"New_deaths"], color = "#af0b1e", linewidth = 2.5)
ax3.plot(deaths["Month"][5:10], deaths["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(deaths["Month"][9:12], deaths["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)

ax1.text(0.5, -80, "0", alpha = 0.5)
ax1.text(3.5, 2000, "1844", alpha = 0.5)
ax1.text(11.5, 2400, "2247", alpha = 0.5)

ax1.text(1.1, -300, "Jan - Mar", color = "#af0b1e", rotation = 2.5, weight = "bold")
ax2.text(3.6, 800, "Mar - Jun", color = "#af0b1e", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#af0b1e", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#af0b1e", weight = "bold", rotation = 45)

ax1.text(0.5, 3500, "Stroytelling of Covid 19 in USA", weight = "bold", size = 15)
ax1.text(0.5, 3100, "Monthly Average Covid's Death", size = 12)

for ax,xm, i in zip(axes, xmax, d):
    ax.axhline(1600, xmin = 0.5, xmax = 0.8, color = "#af0b1e", linewidth = 6, alpha = 0.1)
    ax.axhline(1600, xmin = 0.5, xmax = xm, color = "#af0b1e", linewidth = 6)
    ax.text(7.5, 1850, str(i))



plt.show()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1,figsize = (6,8))


axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(deaths["Month"],deaths["New_deaths"], color = "#af0b1e", alpha = 0.1)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = False)
    for spine in ax.spines.values():
        spine.set_visible(0)

ax1.plot(deaths["Month"][:3], deaths["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(deaths.loc[2:5,"Month"], deaths.loc[2:5,"New_deaths"], color = "#af0b1e", linewidth = 2.5)
ax3.plot(deaths["Month"][5:10], deaths["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(deaths["Month"][9:12], deaths["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)

ax1.text(0.5, -80, "0", alpha = 0.5)
ax1.text(3.5, 2000, "1844", alpha = 0.5)
ax1.text(11.5, 2400, "2247", alpha = 0.5)

ax1.text(1.1, -300, "Jan - Mar", color = "#af0b1e", rotation = 2.5, weight = "bold")
ax2.text(3.6, 800, "Mar - Jun", color = "#af0b1e", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#af0b1e", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#af0b1e", weight = "bold", rotation = 45)

ax1.text(0.5, 3500, "Stroytelling of Covid 19 in USA", weight = "bold", size = 15)
ax1.text(0.5, 3100, "Monthly Average Covid's Death", size = 12)

for ax,xm, i in zip(axes, xmax, d):
    ax.axhline(1600, xmin = 0.5, xmax = 0.8, color = "#af0b1e", linewidth = 6, alpha = 0.1)
    ax.axhline(1600, xmin = 0.5, xmax = xm, color = "#af0b1e", linewidth = 6)
    ax.text(7.5, 1850, format(i, ","), color = "#af0b1e", weight = "bold")


plt.savefig()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#
