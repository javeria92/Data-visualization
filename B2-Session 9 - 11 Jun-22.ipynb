# %% [markdown]
# ### How to imporve Plot Aesthetic

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
degrees = pd.read_csv("degrees.csv")

# %%
degrees.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %%
degrees.tail()
# Out:
#     Year  Agriculture  Architecture  Art and Performance    Biology  \
# 37  2007    47.605026     43.100459                 61.4  59.411993
# 38  2008    47.570834     42.711730                 60.7  59.305765
# 39  2009    48.667224     43.348921                 61.0  58.489583
# 40  2010    48.730042     42.066721                 61.3  59.010255
# 41  2011    50.037182     42.773438                 61.2  58.742397
#
#      Business  Communications and Journalism  Computer Science  Education  \
# 37  49.000459                           62.5              17.6  78.721413
# 38  48.888027                           62.4              17.8  79.196327
# 39  48.840474                           62.8              18.1  79.532909
# 40  48.757988                           62.5              17.6  79.618625
# 41  48.180418                           62.2              18.2  79.432812
#
#     Engineering    English  Foreign Languages  Health Professions  \
# ...

# %%
degrees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           42 non-null     int64
#  1   Agriculture                    42 non-null     float64
#  2   Architecture                   42 non-null     float64
#  3   Art and Performance            42 non-null     float64
#  4   Biology                        42 non-null     float64
#  5   Business                       42 non-null     float64
#  6   Communications and Journalism  42 non-null     float64
#  7   Computer Science               42 non-null     float64
#  8   Education                      42 non-null     float64
#  9   Engineering                    42 non-null     float64
#  10  English                        42 non-null     float64
#  11  Foreign Languages              42 non-null     float64
# ...

# %%
# Randal Olson

# %%
plt.plot(degrees["Year"], degrees["Biology"])
plt.show()

# %%
plt.plot(degrees["Year"], degrees["Biology"], label = "Women", c = "blue")
plt.plot(degrees["Year"], 100 - degrees["Biology"], label = "Men", c = "green")

plt.legend()
plt.show()

# %%
degrees["Biology"].tail(1)
# Out:
# 41    58.742397
# Name: Biology, dtype: float64

# %%
# fig, ax = plt.subplots()

ax = plt.subplot(111)

ax.plot(degrees["Year"], degrees["Biology"], label = "Women", c = "blue")
ax.plot(degrees["Year"], 100 - degrees["Biology"], label = "Men", c = "green")
ax.legend(loc = "upper center")

ax.set_title("Percentage of Biology Degree Awarded By Gender",y = 1.08 )
ax.tick_params(left = False, bottom = False)

plt.show()
# Out:
# left
# right
# bottom
# top

# %%
ax.spines.keys(), ax.spines.values(), ax.spines.items(),
# Out:
# KeysView(<matplotlib.spines.Spines object at 0x000001E837711880>)

# %%
ax = plt.subplot(111)

ax.plot(degrees["Year"], degrees["Biology"], label = "Women", c = "blue")
ax.plot(degrees["Year"], 100 - degrees["Biology"], label = "Men", c = "green")
ax.legend(loc = "upper center")

ax.set_title("Percentage of Biology Degree Awarded By Gender",y = 1.08 )
ax.tick_params(left = False, bottom = False)

ax.spines["right"].set_visible(False)

plt.show()

# %%
ax = plt.subplot(111)

ax.plot(degrees["Year"], degrees["Biology"], label = "Women", c = "blue")
ax.plot(degrees["Year"], 100 - degrees["Biology"], label = "Men", c = "green")
ax.legend(loc = "upper center")

ax.set_title("Percentage of Biology Degree Awarded By Gender",y = 1.08 )
ax.tick_params(left = False, bottom = False)

for v in ax.spines.values():
    v.set_visible(False)

plt.show()

# %%
ax = plt.subplot(111)

ax.plot(degrees["Year"], degrees["Biology"], label = "Women", c = "blue")
ax.plot(degrees["Year"], 100 - degrees["Biology"], label = "Men", c = "green")
ax.legend(loc = "upper center")

ax.set_title("Percentage of Biology Degree Awarded By Gender",y = 1.08 )
ax.tick_params(left = False, bottom = False)

for k in ax.spines.keys():
    ax.spines[k].set_visible(False)

plt.show()

# %%
ax = plt.subplot(111)

ax.plot(degrees["Year"], degrees["Biology"], label = "Women", c = "blue")
ax.plot(degrees["Year"], 100 - degrees["Biology"], label = "Men", c = "green")
ax.legend(loc = "upper center")

ax.set_title("Percentage of Biology Degree Awarded By Gender",y = 1.08 )
ax.tick_params(left = False, bottom = False)

for k in ax.spines:
    ax.spines[k].set_visible(False)

plt.show()

# %%
ax = plt.subplot(111)

ax.plot(degrees["Year"], degrees["Biology"], label = "Women", c = "blue")
ax.plot(degrees["Year"], 100 - degrees["Biology"], label = "Men", c = "green")
ax.legend(loc = "upper center")

ax.set_title("Percentage of Biology Degree Awarded By Gender",y = 1.08 )
ax.tick_params(left = False, bottom = False)

for k,v in ax.spines.items():
    ax.spines[k].set_visible(False)
    v.set_visible(False)

plt.show()

# %%
ax = plt.subplot(111)

ax.plot(degrees["Year"], degrees["Biology"], label = "Women", c = "blue")
ax.plot(degrees["Year"], 100 - degrees["Biology"], label = "Men", c = "green")
ax.legend(loc = "upper center")

ax.set_title("Percentage of Biology Degree Awarded By Gender",y = 1.08 )
ax.tick_params(left = False, bottom = False)

for k,v in ax.spines.items():
    v.set_visible(False)
    ax.spines[k].set_visible(False)
    

plt.show()

# %%
degrees.columns
# Out:
# Index(['Year', 'Agriculture', 'Architecture', 'Art and Performance', 'Biology',
#        'Business', 'Communications and Journalism', 'Computer Science',
#        'Education', 'Engineering', 'English', 'Foreign Languages',
#        'Health Professions', 'Math and Statistics', 'Physical Sciences',
#        'Psychology', 'Public Administration', 'Social Sciences and History'],
#       dtype='object')

# %%
major_cats = ['Biology', 'Computer Science', 'Engineering', 'Math and Statistics']

fig = plt.figure(figsize = (12,12))

for i in range(4):
    ax = fig.add_subplot(2,2,i+1)
    ax.plot(degrees["Year"], degrees[major_cats[i]], label = "Women", c = "blue")
    ax.plot(degrees["Year"], 100 - degrees[major_cats[i]], label = "Men", c = "green")
    ax.tick_params(bottom = False, left = False)
    
    ax.set_xlim(1968,  2011)
    ax.set_ylim(0,100)
    ax.set_title(major_cats[i])
    
    for v in ax.spines.values():
        v.set_visible(False)
        
    ax.legend(loc = "best")
    

plt.show()

# %%
major_cats = ['Biology', 'Computer Science', 'Engineering', 'Math and Statistics']

# fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (12,12), sharex = True, sharey = True)
fig, ax = plt.subplots(2, 2, figsize = (8,8), sharex = True, sharey = True)

ax1, ax2, ax3, ax4 = ax.flatten()

axes = [ax1, ax2, ax3, ax4]

for i in range(4):
    axes[i].plot(degrees["Year"], degrees[major_cats[i]], label = "Women", c = "blue")
    axes[i].plot(degrees["Year"], 100 - degrees[major_cats[i]], label = "Men", c = "green")
    axes[i].tick_params(bottom = False, left = False)
    
    axes[i].set_xlim(1968,  2011)
    axes[i].set_ylim(0,100)
    axes[i].set_title(major_cats[i])
    
    for v in axes[i].spines.values():
        v.set_visible(False)
        
    axes[i].legend(loc = "best")
    

plt.show()

# %%
major_cats = ['Biology', 'Computer Science', 'Engineering', 'Math and Statistics']

# fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (12,12), sharex = True, sharey = True)
fig, ((ax1, ax2), (ax3, ax4) ) = plt.subplots(2, 2, figsize = (8,8), sharex = True, sharey = True)

# ax1, ax2, ax3, ax4 = ax.flatten()

axes = [ax1, ax2, ax3, ax4]

for i in range(4):
    axes[i].plot(degrees["Year"], degrees[major_cats[i]], label = "Women", c = "blue")
    axes[i].plot(degrees["Year"], 100 - degrees[major_cats[i]], label = "Men", c = "green")
    axes[i].tick_params(bottom = False, left = False)
    
    axes[i].set_xlim(1968,  2011)
    axes[i].set_ylim(0,100)
    axes[i].set_title(major_cats[i])
    
    for v in axes[i].spines.values():
        v.set_visible(False)
        
    axes[i].legend(loc = "best")
    

plt.show()

# %%
major_cats = ['Biology', 'Computer Science', 'Engineering', 'Math and Statistics']

fig = plt.figure(figsize = (6,6))

for i in range(4):
    ax = fig.add_subplot(2,2,i+1)
    ax.plot(degrees["Year"], degrees[major_cats[i]], label = "Women", c = "blue")
    ax.plot(degrees["Year"], 100 - degrees[major_cats[i]], label = "Men", c = "green")
    ax.tick_params(bottom = False, left = False)
    
    ax.set_xlim(1968,  2011)
    ax.set_ylim(0,100)
    ax.set_title(major_cats[i])
    
    for v in ax.spines.values():
        v.set_visible(False)
        
    ax.legend(loc = "best")
    

plt.show()

# %%
major_cats = ['Biology', 'Computer Science', 'Engineering', 'Math and Statistics']

fig = plt.figure(figsize = (6,6))

fig.subplots_adjust(hspace = 0.5, wspace = .3)

for i in range(4):
    ax = fig.add_subplot(2,2,i+1)
    ax.plot(degrees["Year"], degrees[major_cats[i]], label = "Women", c = "blue")
    ax.plot(degrees["Year"], 100 - degrees[major_cats[i]], label = "Men", c = "green")
    ax.tick_params(bottom = False, left = False)
    
    ax.set_xlim(1968,  2011)
    ax.set_ylim(0,100)
    ax.set_title(major_cats[i])
    
    for v in ax.spines.values():
        v.set_visible(False)
        
    ax.legend(loc = "best")
    

plt.show()

# %%
major_cats = ['Biology', 'Computer Science', 'Engineering', 'Math and Statistics']

# fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (12,12), sharex = True, sharey = True)
fig, ax = plt.subplots(2, 2, figsize = (7,7), sharex = True, sharey = True)
fig.subplots_adjust(hspace = 0.2, wspace = 0.3)

ax1, ax2, ax3, ax4 = ax.flatten()

axes = [ax1, ax2, ax3, ax4]

for i in range(4):
    axes[i].plot(degrees["Year"], degrees[major_cats[i]], label = "Women", c = "blue")
    axes[i].plot(degrees["Year"], 100 - degrees[major_cats[i]], label = "Men", c = "green")
    axes[i].tick_params(bottom = False, left = False)
    
    axes[i].set_xlim(1968,  2011)
    axes[i].set_ylim(0,100)
    axes[i].set_title(major_cats[i])
    
    for v in axes[i].spines.values():
        v.set_visible(False)
        
    axes[i].legend(loc = "best")
    

plt.show()

# %%
db = (0/255,107/255,164/255)
orange = (240/255,120/255,10/255)
